# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from word2number import w2n
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
data=pd.read_csv('Automobile_data.csv')

# %%
data
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
data.dtypes
# Out:
# index                 int64
# company              object
# body-style           object
# wheel-base          float64
# length              float64
# engine-type          object
# num-of-cylinders     object
# horsepower            int64
# average-mileage       int64
# price               float64
# dtype: object

# %%
data.drop('index',axis=1)
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 56   volkswagen        sedan        97.3   171.7         ohc             four
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
#
# ...

# %%
data.isna().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
price_mean=data['price'].mean()
price_mean
# Out:
# 15387.0

# %%
data['price']=data['price'].fillna(price_mean)

# %%
data
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
data['num-of-cylinders']=data['num-of-cylinders'].apply(w2n.word_to_num)

# %%
le_company=LabelEncoder()
le_bodystyle=LabelEncoder()
le_enginetype=LabelEncoder()

data['company']=le_company.fit_transform(data['company'])
data['body-style']=le_bodystyle.fit_transform(data['body-style'])
data['engine-type']=le_enginetype.fit_transform(data['engine-type'])

# %%
data=data.drop('index', axis=1)

# %%
data
# Out:
#     company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# 0         0           0        88.6   168.8            0                 4
# 1         0           0        88.6   168.8            0                 4
# 2         0           2        94.5   171.2            5                 6
# 3         1           3        99.8   176.6            3                 4
# 4         1           3        99.4   176.6            3                 5
# ..      ...         ...         ...     ...          ...               ...
# 56       14           3        97.3   171.7            3                 4
# 57       14           3        97.3   171.7            3                 4
# 58       14           3        97.3   171.7            3                 4
# 59       15           3       104.3   188.8            3                 4
# 60       15           4       104.3   188.8            3                 4
#
#     horsepower  average-mileage    price
# ...

# %%
x=data.drop('price',axis=1)
y=data['price']

# %%
x
# Out:
#     company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# 0         0           0        88.6   168.8            0                 4
# 1         0           0        88.6   168.8            0                 4
# 2         0           2        94.5   171.2            5                 6
# 3         1           3        99.8   176.6            3                 4
# 4         1           3        99.4   176.6            3                 5
# ..      ...         ...         ...     ...          ...               ...
# 56       14           3        97.3   171.7            3                 4
# 57       14           3        97.3   171.7            3                 4
# 58       14           3        97.3   171.7            3                 4
# 59       15           3       104.3   188.8            3                 4
# 60       15           4       104.3   188.8            3                 4
#
#     horsepower  average-mileage
# 0          111               21
# ...

# %%
y
# Out:
# 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 56     7975.0
# 57     7995.0
# 58     9995.0
# 59    12940.0
# 60    13415.0
# Name: price, Length: 61, dtype: float64

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=2)

# %%
Gdr= GradientBoostingRegressor(n_estimators=750, learning_rate=0.05, random_state=100)

# %%
Gdr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, n_estimators=750,
#                           random_state=100)

# %%
Gdr.score(x_test,y_test)
# Out:
# 0.7625202415326551
