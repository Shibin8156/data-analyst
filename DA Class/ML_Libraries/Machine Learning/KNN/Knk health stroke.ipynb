# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
data=pd.read_csv('healthcare-dataset-stroke-data.csv')
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
data=data.drop('id',axis=1)
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
a= LabelEncoder()
data['gender'] =a.fit_transform(data['gender'])
b= LabelEncoder()
data['ever_married'] =b.fit_transform(data['ever_married'])
c= LabelEncoder()
data['work_type'] =c.fit_transform(data['work_type'])
d= LabelEncoder()
data['Residence_type'] =d.fit_transform(data['Residence_type'])
e= LabelEncoder()
data['smoking_status'] =e.fit_transform(data['smoking_status'])

# %%
data
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
data['bmi'].fillna(data['bmi'].mean(), inplace=True)

# %%
data
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status  stroke
# ...

# %%
x=data.drop('stroke', axis=1)
y=data['stroke']

# %%
x
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.20, random_state=6)

# %%
model=KNeighborsClassifier(n_neighbors=20)

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
model.score(x_test,y_test)
# Out:
# 0.9500978473581213

# %%
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
model2=KNeighborsClassifier(n_neighbors=20)

# %%
model2.fit(x_train_scaled,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
model2.score(x_test_scaled,y_test)
# Out:
# 0.9500978473581213

# %%
scaler1=MinMaxScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
mode=KNeighborsClassifier(n_neighbors=20)

# %%
mode.fit(x_train_scaled,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
mode.score(x_test_scaled,y_test)
# Out:
# 0.9500978473581213

# %%
mode.score(x_test_scaled,y_test)
# Out:
# 0.9500978473581213
