# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
boston_data=pd.read_csv('Boston.csv')
boston_data
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
boston=boston_data.drop('Unnamed: 0', axis=1)
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
x= boston_data.drop('medv', axis=1)
y= boston_data['medv']

# %% [markdown]
# ### 07-06-23

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y ,test_size= 0.3, random_state=24)

# %%
x_train.shape, y_train.shape
# Out:
# ((354, 14), (354,))

# %%
x_test.shape,y_test.shape
# Out:
# ((152, 14), (152,))

# %%
x_train
# Out:
#      Unnamed: 0      crim    zn  indus  chas     nox     rm    age     dis  \
# 64           65   0.01951  17.5   1.38     0  0.4161  7.104   59.5  9.2229
# 238         239   0.08244  30.0   4.93     0  0.4280  6.481   18.5  6.1899
# 94           95   0.04294  28.0  15.04     0  0.4640  6.249   77.3  3.6150
# 132         133   0.59005   0.0  21.89     0  0.6240  6.372   97.9  2.3274
# 366         367   3.69695   0.0  18.10     0  0.7180  4.963   91.4  1.7523
# ..          ...       ...   ...    ...   ...     ...    ...    ...     ...
# 401         402  14.23620   0.0  18.10     0  0.6930  6.343  100.0  1.5741
# 343         344   0.02543  55.0   3.78     0  0.4840  6.696   56.4  5.7321
# 192         193   0.08664  45.0   3.44     0  0.4370  7.178   26.3  6.4798
# 387         388  22.59710   0.0  18.10     0  0.7000  5.000   89.5  1.5184
# 418         419  73.53410   0.0  18.10     0  0.6790  5.957  100.0  1.8026
#
#      rad  tax  ptratio   black  lstat
# 64     3  216     18.6  393.24   8.05
# 238    6  300     16.6  379.41   6.36
# 94     4  270     18.2  396.90  10.59
# 132    4  437     21.2  385.76  11.12
# 366   24  666     20.2  316.03  14.00
# ..   ...  ...      ...     ...    ...
# 401   24  666     20.2  396.90  20.32
# 343    5  370     17.6  396.90   7.18
# 192    5  398     15.2  390.49   2.87
# 387   24  666     20.2  396.90  31.99
# 418   24  666     20.2   16.45  20.62
#
# [354 rows x 14 columns]

# %%
model =LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# 29.548639286863747
# [-1.95641653e-03 -5.86180464e-02  3.85416816e-02 -1.11917750e-02
#   2.99215287e+00 -1.28121770e+01  4.29954359e+00 -1.04342015e-02
#  -1.40581848e+00  2.55872633e-01 -1.11712376e-02 -8.50733822e-01
#   1.04985651e-02 -5.09050459e-01]

# %%
y_pred =model.predict (x_test)

# %%
prediction_table= pd.DataFrame({'Target y values': y_test, 'Predicted y values': y_pred})
prediction_table
# Out:
#      Target y values  Predicted y values
# 368             50.0           22.503593
# 105             19.5           18.723244
# 269             20.7           25.672388
# 119             19.3           21.014744
# 351             24.1           20.700128
# ..               ...                 ...
# 406             11.9            7.505752
# 51              20.5           23.972520
# 504             22.0           26.173023
# 324             25.0           25.470289
# 500             16.8           20.226858
#
# [152 rows x 2 columns]

# %%
plt.scatter(y_test,y_pred)

# %%
#  evaluvating model on training  data 
model.score(x_train, y_train)
# Out:
# 0.7451363010607874

# %%
# evaluating model on testing data
model.score(x_test, y_test)
# Out:
# 0.715150088371947
