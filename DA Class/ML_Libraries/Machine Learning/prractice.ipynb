# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from word2number import w2n

# %%
data=pd.read_csv('bodyPerformance.csv')
data
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0      27.0      M      172.3      75.24        21.3       80.0     130.0
# 1      25.0      M      165.0      55.80        15.7       77.0     126.0
# 2      31.0      M      179.6      78.00        20.1       92.0     152.0
# 3      32.0      M      174.5      71.10        18.4       76.0     147.0
# 4      28.0      M      173.8      67.70        17.1       70.0     127.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13388  25.0      M      172.1      71.80        16.2       74.0     141.0
# 13389  21.0      M      179.7      63.90        12.1       74.0     128.0
# 13390  39.0      M      177.2      80.50        20.1       78.0     132.0
# 13391  64.0      F      146.1      57.70        40.4       68.0     121.0
# 13392  34.0      M      164.0      66.10        19.5       82.0     150.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
dummies= pd.get_dummies(data.gender)
dummies
# Out:
#        F  M
# 0      0  1
# 1      0  1
# 2      0  1
# 3      0  1
# 4      0  1
# ...   .. ..
# 13388  0  1
# 13389  0  1
# 13390  0  1
# 13391  1  0
# 13392  0  1
#
# [13393 rows x 2 columns]

# %%
new_data= pd.concat([data, dummies], axis=1)
new_data
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0      27.0      M      172.3      75.24        21.3       80.0     130.0
# 1      25.0      M      165.0      55.80        15.7       77.0     126.0
# 2      31.0      M      179.6      78.00        20.1       92.0     152.0
# 3      32.0      M      174.5      71.10        18.4       76.0     147.0
# 4      28.0      M      173.8      67.70        17.1       70.0     127.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13388  25.0      M      172.1      71.80        16.2       74.0     141.0
# 13389  21.0      M      179.7      63.90        12.1       74.0     128.0
# 13390  39.0      M      177.2      80.50        20.1       78.0     132.0
# 13391  64.0      F      146.1      57.70        40.4       68.0     121.0
# 13392  34.0      M      164.0      66.10        19.5       82.0     150.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm  \
# ...

# %%
new_data= new_data.drop('gender', axis=1)
new_data
# Out:
#         age  height_cm  weight_kg  body fat_%  diastolic  systolic  gripForce  \
# 0      27.0      172.3      75.24        21.3       80.0     130.0       54.9
# 1      25.0      165.0      55.80        15.7       77.0     126.0       36.4
# 2      31.0      179.6      78.00        20.1       92.0     152.0       44.8
# 3      32.0      174.5      71.10        18.4       76.0     147.0       41.4
# 4      28.0      173.8      67.70        17.1       70.0     127.0       43.5
# ...     ...        ...        ...         ...        ...       ...        ...
# 13388  25.0      172.1      71.80        16.2       74.0     141.0       35.8
# 13389  21.0      179.7      63.90        12.1       74.0     128.0       33.0
# 13390  39.0      177.2      80.50        20.1       78.0     132.0       63.5
# 13391  64.0      146.1      57.70        40.4       68.0     121.0       19.3
# 13392  34.0      164.0      66.10        19.5       82.0     150.0       35.9
#
# ...

# %%
new_data.drop('gender', axis=1)
new_data

# %%
new_data
# Out:
#         age  height_cm  weight_kg  body fat_%  diastolic  systolic  gripForce  \
# 0      27.0      172.3      75.24        21.3       80.0     130.0       54.9
# 1      25.0      165.0      55.80        15.7       77.0     126.0       36.4
# 2      31.0      179.6      78.00        20.1       92.0     152.0       44.8
# 3      32.0      174.5      71.10        18.4       76.0     147.0       41.4
# 4      28.0      173.8      67.70        17.1       70.0     127.0       43.5
# ...     ...        ...        ...         ...        ...       ...        ...
# 13388  25.0      172.1      71.80        16.2       74.0     141.0       35.8
# 13389  21.0      179.7      63.90        12.1       74.0     128.0       33.0
# 13390  39.0      177.2      80.50        20.1       78.0     132.0       63.5
# 13391  64.0      146.1      57.70        40.4       68.0     121.0       19.3
# 13392  34.0      164.0      66.10        19.5       82.0     150.0       35.9
#
# ...

# %%
le_company=LabelEncoder()
le_bodystyle=LabelEncoder()
le_enginetype=LabelEncoder()

data['class']=le_company.fit_transform(data['class'])

# %%
x
# Out:
#         age  height_cm  weight_kg  body fat_%  diastolic  systolic  gripForce  \
# 0      27.0      172.3      75.24        21.3       80.0     130.0       54.9
# 1      25.0      165.0      55.80        15.7       77.0     126.0       36.4
# 2      31.0      179.6      78.00        20.1       92.0     152.0       44.8
# 3      32.0      174.5      71.10        18.4       76.0     147.0       41.4
# 4      28.0      173.8      67.70        17.1       70.0     127.0       43.5
# ...     ...        ...        ...         ...        ...       ...        ...
# 13388  25.0      172.1      71.80        16.2       74.0     141.0       35.8
# 13389  21.0      179.7      63.90        12.1       74.0     128.0       33.0
# 13390  39.0      177.2      80.50        20.1       78.0     132.0       63.5
# 13391  64.0      146.1      57.70        40.4       68.0     121.0       19.3
# 13392  34.0      164.0      66.10        19.5       82.0     150.0       35.9
#
# ...

# %%
y
# Out:
# 0        C
# 1        A
# 2        C
# 3        B
# 4        B
#         ..
# 13388    C
# 13389    D
# 13390    A
# 13391    D
# 13392    C
# Name: class, Length: 13393, dtype: object

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.25, random_state=7)

# %%
model=RandomForestRegressor(n_estimators=23,random_state=90)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 model=RandomForestRegressor(n_estimators=23,random_state=90)
# ----> 2 model.fit(x_train,y_train)
#       3 model.score(x_test,y_test)
#
# File C:\Program Files\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:388, in BaseForest.fit(self, X, y, sample_weight)
#     385 y, expanded_class_weight = self._validate_y_class_weight(y)
#     387 if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
# --> 388     y = np.ascontiguousarray(y, dtype=DOUBLE)
#     390 if expanded_class_weight is not None:
#     391     if sample_weight is not None:
#
# ValueError: could not convert string to float: 'C'
